# %% [markdown]
# From
# https://towardsdatascience.com/a-practitioners-guide-to-natural-language-processing-part-i-processing-understanding-text-9f4abfd13e72

# %% [markdown]
# ### CRISP-DM model
# ![image.png](attachment:image.png)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
seed_urls = ['https://inshorts.com/en/read/technology',
             'https://inshorts.com/en/read/sports',
             'https://inshorts.com/en/read/world']

def build_dataset(seed_urls):
    news_data = []
    for url in seed_urls:
        news_category = url.split('/')[-1]
        data = requests.get(url)
        soup = BeautifulSoup(data.content, 'html.parser')
        
        news_articles = [{'news_headline': headline.find('span', 
                                                         attrs={"itemprop": "headline"}).string,
                          'news_article': article.find('div', 
                                                       attrs={"itemprop": "articleBody"}).string,
                          'news_category': news_category}
                         
                            for headline, article in 
                             zip(soup.find_all('div', 
                                               class_=["news-card-title news-right-box"]),
                                 soup.find_all('div', 
                                               class_=["news-card-content news-right-box"]))
                        ]
        news_data.extend(news_articles)
        
    df =  pd.DataFrame(news_data)
    df = df[['news_headline', 'news_article', 'news_category']]
    return df

# %%
df = build_dataset(seed_urls)
df
# Out:
#                                         news_headline  \
# 0   Ronaldo becomes first person to reach 25 crore...
# 1   Julian Assange can't be extradited to US due t...
# 2   Slack down for many users worldwide, messages ...
# 3   Jack Ma suspected to be missing for 2 months a...
# 4   When did billionaire Jack Ma criticise Chinese...
# ..                                                ...
# 70  100 killed by suspected Islamist militants in ...
# 71  British diplomat, who helped establish the UN,...
# 72  US Congress passes 'Malala Yousafzai Scholarsh...
# 73  3 family members killed after their plane cras...
# 74  My evil handlers can no longer control me: Gre...
#
#                                          news_article news_category
# 0   Juventus star forward Cristiano Ronaldo has be...    technology
# 1   A British judge on Monday rejected the US' req...    technology
# 2   Several Slack users from across the world repo...    technology
# 3   Chinese billionaire and Alibaba Co-Founder Jac...    technology
# 4   Billionaire Jack Ma criticised Chinese regulat...    technology
# ..                                                ...           ...
# 70  One hundred people were killed on Saturday in ...         world
# 71  British diplomat Sir Brian Urquhart who played...         world
# 72  The US Congress has passed the 'Malala Yousafz...         world
# 73  Three members of a family were killed after a ...         world
# 74  Swedish climate activist Greta Thunberg turned...         world
#
# [75 rows x 3 columns]

# %% [markdown]
# # Pre-processing
