# %% [markdown]
# # Linear Search

# %% [markdown]
# ![2020-01-19%2021_11_57-Window.png](attachment:2020-01-19%2021_11_57-Window.png)

# %%
A = [5,1,4,3,2,9,8,7,6]

toBeFound = 3
found = False # our loop invariant: if the value is not found, this is always false.
for item in A:
    if (item == toBeFound):
        found = True
        break
if found: print("Found")
# Out:
# Found
