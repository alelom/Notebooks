# %% [markdown]
# # Selection Sort

# %% [markdown]
# ![2020-01-19%2021_23_52-Window.png](attachment:2020-01-19%2021_23_52-Window.png)

# %%
A = [5,1,4,3,2,9,8,7,6]

for i in range(0, len(A)):
    minIdx = i
    minValue = A[i]
    for j in range(i, len(A)):
        if (A[j] < minValue):
            minValue = A[j]
            minIdx = j
    A[minIdx] = A[i]
    A[i] = minValue

A
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
