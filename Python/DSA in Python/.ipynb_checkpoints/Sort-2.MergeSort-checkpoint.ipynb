# %% [markdown]
# # Merge sort

# %% [markdown]
# Good explanation: https://www.programiz.com/dsa/merge-sort

# %% [markdown]
# From https://www.khanacademy.org/computing/computer-science/algorithms/merge-sort/a/overview-of-merge-sort
#
# ![ace963383bea8d154f6abd1322a06a73b56b4628.png](attachment:ace963383bea8d154f6abd1322a06a73b56b4628.png)
#
# The mergeSort function should recursively sort the subarray array[p..r] i.e. after calling mergeSort(array,p,r) the elements from index p to index r of array should be sorted in ascending order.
#
# To remind you of the merge sort algorithm:
# - If the subarray has size 0 or 1, then it's already sorted, and so nothing needs to be done.
# - Otherwise, merge sort uses divide-and-conquer to sort the subarray.
#
# Use merge(array, p, q, r) to merge sorted sub arrays array[p..q] and array[q+1..r].

# %% [markdown]
# [Pseudocode](https://rosettacode.org/wiki/Sorting_algorithms/Merge_sort):
# ```js
# function mergesort(m)
#    var list left, right, result
#    if length(m) ≤ 1
#        return m
#    else
#        var middle = length(m) / 2
#        for each x in m up to middle - 1
#            add x to left
#        for each x in m at and after middle
#            add x to right
#        left = mergesort(left)
#        right = mergesort(right)
#        if last(left) ≤ first(right)
#           append right to left
#           return left
#        result = merge(left, right)
#        return result
#
# function merge(left,right)
#    var list result
#    while length(left) > 0 and length(right) > 0
#        if first(left) ≤ first(right)
#            append first(left) to result
#            left = rest(left)
#        else
#            append first(right) to result
#            right = rest(right)
#    if length(left) > 0
#        append rest(left) to result
#    if length(right) > 0
#        append rest(right) to result
#    return result
# ```

# %% [markdown]
# ### Analysis of the merge sort
# https://www.khanacademy.org/computing/computer-science/algorithms/merge-sort/a/analysis-of-merge-sort
