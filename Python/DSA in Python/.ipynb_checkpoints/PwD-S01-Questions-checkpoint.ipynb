# %% [markdown]
# # 1
#
# <img src="attachment:2020-01-21%2020_08_29-Window.png" width="400">

# %%
import random

def generateOrderedRandomNums(totalNumbers=100, maxValue=1000, seed=random.random()):
    random.seed(seed)
    maxValue = totalNumbers*10
    
    step = maxValue//totalNumbers
    output = []
    for i in range(totalNumbers):
        output.append(i*step + random.randint(1,step))
    return output

generateOrderedRandomNums(10)
# Out:
# [9, 15, 27, 36, 47, 57, 63, 74, 86, 92]

# %%
import random


def generateOrderedRandomNums(totalNumbers=100, maxValue=1000, maxDistance = None, seed=random.random()):

    random.seed(seed)
    maxValue = totalNumbers*10
    
    if (maxDistance == None):
        step = maxValue//totalNumbers
        maxDistance = step
        minRand = 0
    else:
        step = 1
        minRand = 1
        
    output = []
    for i in range(totalNumbers):
        randNo = random.randint(i*step,i*step+maxDistance)
        print(f"step: {i*step}, randNo : {randNo}")
        output.append(i*step + randNo)
    return output

print(generateOrderedRandomNums(10, 100, 5))
