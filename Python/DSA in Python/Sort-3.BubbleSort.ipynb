# %% [markdown]
# # Bubble Sort

# %% [markdown]
# ![2020-01-20%2008_32_41-Window.png](attachment:2020-01-20%2008_32_41-Window.png)
# ![2020-01-20%2008_32_51-Window.png](attachment:2020-01-20%2008_32_51-Window.png)

# %%
A = [5,1,4,3,2,9,8,7,6]

for i in range(len(A)):
    for j in range(i+1, len(A)):
        if A[i]>A[j]:
            temp = A[j]
            A[j] = A[i]
            A[i] = temp
A
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
